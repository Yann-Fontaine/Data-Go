# %% [markdown]
# # IMPORT PANDAS & SEABORN

# %%
import pandas as pd
import seaborn as sns

# %% [markdown]
# # IMPORT CSV DATAS

# %%
df = pd.read_csv('data.csv')
pd.read_csv('data.csv')
# Out:
#       year                    reg_name  \
# 0     2013  Provence-Alpes-Côte d'Azur
# 1     2013  Provence-Alpes-Côte d'Azur
# 2     2013  Provence-Alpes-Côte d'Azur
# 3     2013  Provence-Alpes-Côte d'Azur
# 4     2013  Provence-Alpes-Côte d'Azur
# ...    ...                         ...
# 9188  2013                  La Réunion
# 9189  2013                  La Réunion
# 9190  2013                  La Réunion
# 9191  2013                  La Réunion
# 9192  2013                  La Réunion
#
#                                      tax_name        amount
# 0                         Charges financières  6.709871e+07
# 1                                        CVAE  2.580641e+08
# 2                          Frais de personnel  2.302554e+08
# 3                             Impôts et taxes  9.147599e+08
# 4                   Recettes d'investissement  3.356027e+08
# ...                                       ...           ...
# 9188                         Dépôts au Trésor  1.533673e+08
# ...

# %% [markdown]
# # DISPLAY ALL DATAS (pivoted)

# %%
table = pd.pivot_table(df, index=['reg_name', 'year'], columns=['tax_name'])
pd.pivot_table(df, index=['reg_name', 'year'], columns=['tax_name'])
# Out:
#                                               amount                  \
# tax_name                  Achats et charges externes Allocations APA
# reg_name             year
# Auvergne-Rhône-Alpes 2012               8.965651e+07             NaN
#                      2013               9.328090e+07             NaN
#                      2014               9.244586e+07             NaN
#                      2015               9.549567e+07             NaN
#                      2016               1.687399e+08             NaN
# ...                                              ...             ...
# Île-de-France        2015               2.509597e+08             NaN
#                      2016               2.975984e+08             NaN
#                      2017               2.966393e+08             NaN
#                      2018               2.709781e+08             NaN
#                      2019               2.846426e+08             NaN
#
# ...

# %% [markdown]
# # TRYING A FIRST VISUALIZATION

# %%
sns.pairplot(data=df, hue = 'reg_name')

# %% [markdown]
# # TRYING TO VISUALIZE SOME INTERESTING FACTS

# %%
sns.catplot(data=df, x="tax_name", y='amount', hue="reg_name")

# %% [markdown]
# # EXERCISE 3

# %%
import pandas as pd
import datetime

df = pd.read_pickle("./data.pickle")
prices = df['Price'].to_numpy()
dates = df['Date'].to_numpy()
x_buffer = [d.split('T') for d in dates]
x_values = []
for value in x_buffer:
    x_values.append(value[0])
print(x_values)
# Out:
# ['2020-12-17', '2020-12-17', '2020-12-16', '2020-12-16', '2020-12-16', '2020-12-16', '2020-12-16', '2020-12-15', '2020-12-15', '2020-12-14', '2020-12-14', '2020-12-14', '2020-12-13', '2020-12-13', '2020-12-13', '2020-12-13', '2020-12-13', '2020-12-13', '2020-12-12', '2020-12-12', '2020-12-12', '2020-12-11', '2020-12-10', '2020-12-10', '2020-12-09', '2020-12-09', '2020-12-08', '2020-12-02', '2020-11-28', '2020-11-27', '2020-11-24', '2020-11-23', '2020-11-22', '2020-11-18', '2020-11-18']

# %%
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from matplotlib import style

style.use('fivethirtyeight')

fig = plt.figure()
ax1 = fig.add_subplot(1,1,1)

def animate(i):
    xs = []
    ys = []
    index = 0
    for price in prices:
        xs.append(float(price))
        ys.append(x_values[index])
        index += 1
    ax1.clear()
    ax1.plot(xs, ys)
    
ani = animation.FuncAnimation(fig, animate, interval=1000)
plt.show()

# %%
import seaborn as sns

sns.set_theme(style="darkgrid")
sns.lineplot(x=x_values, y=prices)
# Out:
# <AxesSubplot:>
